# %% [markdown]
# ## <font color='#89cff0'>Diabetes<font/>

# %%
from sklearn.datasets import load_diabetes

df = load_diabetes(as_frame=True)
df.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
df.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
df.data
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
df.frame
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## <font color='#89cff0'>Histogram Analysis of Target Variable<font/>

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(figsize=(9,6))
plt.hist(df["target"],25)
plt.xlabel("target")
plt.show()

# %% [markdown]
# <font color='#89cff0'>The distribution of the disease progression outcomes is skewed towards the lower values.<font/>

# %% [markdown]
# ---

# %% [markdown]
#  ## <font color='#89cff0'>Heatmap Visualization of Correlation Coefficients<fonmt/>

# %%
df.data.corr().round(2)
# Out:
#       age   sex   bmi    bp    s1    s2    s3    s4    s5    s6
# age  1.00  0.17  0.19  0.34  0.26  0.22 -0.08  0.20  0.27  0.30
# sex  0.17  1.00  0.09  0.24  0.04  0.14 -0.38  0.33  0.15  0.21
# bmi  0.19  0.09  1.00  0.40  0.25  0.26 -0.37  0.41  0.45  0.39
# bp   0.34  0.24  0.40  1.00  0.24  0.19 -0.18  0.26  0.39  0.39
# s1   0.26  0.04  0.25  0.24  1.00  0.90  0.05  0.54  0.52  0.33
# s2   0.22  0.14  0.26  0.19  0.90  1.00 -0.20  0.66  0.32  0.29
# s3  -0.08 -0.38 -0.37 -0.18  0.05 -0.20  1.00 -0.74 -0.40 -0.27
# s4   0.20  0.33  0.41  0.26  0.54  0.66 -0.74  1.00  0.62  0.42
# s5   0.27  0.15  0.45  0.39  0.52  0.32 -0.40  0.62  1.00  0.46
# s6   0.30  0.21  0.39  0.39  0.33  0.29 -0.27  0.42  0.46  1.00

# %% [markdown]
# <font color='#89cff0'> Values close to +1 indicate a strong positive correlation, while those near -1 denote a strong negative correlation. A value near zero suggests no correlation between the two variables. Negative correlation might imply deteriorating health outcomes as blood sugar levels increase, or conversely, an improvement in health indicators with a decrease in blood sugar levels. <font/>

# %%
import seaborn as sns

sns.set_style('darkgrid')
sns.set_context('notebook')
cmap = sns.color_palette('Blues')


f, ax = plt.subplots(figsize=(9,6))
sns.heatmap(data=df.frame.corr().round(2), 
            annot=True, 
            cmap=cmap, 
            linewidths=2,
            ax=ax).xaxis.tick_top()
plt.show()

# %% [markdown]
# <font color='#89cff0'>The target variable has the highest correlation with bmi and s5 variables, some correlation also present between bmi and s5. </font>

# %% [markdown]
# ---

# %% [markdown]
# ## <font color='#89cff0'>Target Variable Dependence and Scatter Plots
#
#
# Combine DataFrames : Concatenating both X and Y dataframes into one single dataframe</font>

# %%
import pandas as pd

X_df = pd.DataFrame(df.data) # Independent variable
y_df = pd.DataFrame(df.target) # Dependent variable

# %% [markdown]
# <font color='#89cff0'>Combine DataFrames : Concatenating both X and Y dataframes into one single dataframe
#  </font>

# %%
df = pd.concat([X_df, y_df], axis = 1) 
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## <font color='#89cff0'>Scatter plot </font>

# %%
plt.figure(figsize=(17, 8))
plt.subplot(1,2,1)
sns.scatterplot(x='target',
                 y='bmi',
                 data=df).set(title='bmi vs. Target')

plt.subplot(1,2,2)
sns.scatterplot(x='target', 
                y='s5',
                data=df).set(title='s5 vs. Target')
plt.show()

# %% [markdown]
# <font color='#89cff0'>Both variables have linear influence on the target variable.
#
# Correlation Analysis between Target Variable and Independent Features</font>

# %% [markdown]
# ---

# %% [markdown]
# ## <font color='#89cff0'>Correlation Analysis between Target Variable and Independent Features
#
#
#
#
# </font>

# %%
correlation_matrix = df.corr(method='pearson')
target_correlation = correlation_matrix['target'].drop('target')

# %%
target_correlation.to_frame().T.round(2)
# Out:
#          age   sex   bmi    bp    s1    s2    s3    s4    s5    s6
# target  0.19  0.04  0.59  0.44  0.21  0.17 -0.39  0.43  0.57  0.38

# %%
plt.subplots(figsize=(9,1))
sns.heatmap(target_correlation.to_frame().T, 
            annot=True,
            linewidths=.2,
            cbar=False,
            cmap=cmap
            ).xaxis.tick_top()

# %% [markdown]
# <font color='#89cff0'>Target variable has the strongest positive linear relationship with bmi and negative linear relationship with s3.
#
#
#
#
# </font>

# %%
import numpy as np

corr = X_df.corr()
mask = np.triu(X_df.corr())
f, ax = plt.subplots(figsize=(9, 6))

sns.heatmap(corr[::-1].round(2), 
            cmap=cmap, 
            center=0,
            annot=True,
            square=True,
            mask=mask[::-1, :],
            linewidths=2,
            ax=ax
           ).xaxis.tick_top()

# %% [markdown]
# <font color='#89cff0'>Variables s1 and s2 are highly correlated, as are s3 and s4. Let's see how s2 and s1 relate to each other on the scatter plot.</font>

# %%
f, ax = plt.subplots(figsize=(9,6))
sns.scatterplot(x='s1', 
                y='s2',
                data=df,
                ax=ax
                ).set(title='s2 vs. s1')
# Out:
# [Text(0.5, 1.0, 's2 vs. s1')]

# %% [markdown]
# Values increase in both axes

# %% [markdown]
# ---

# %% [markdown]
# ### <font color='#89cff0'>Data Preparation: Training and Testing Split</font>

# %%
from sklearn.model_selection import train_test_split

remove = ['age','s1','s2','s3','s4','s6','target']

X = df.drop(remove, axis=1) 
y = df.target 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state=42)

# %% [markdown]
# ---

# %% [markdown]
# ### <font color='#89cff0'>Add constant term for the Intercept</font>

# %%
import statsmodels.api as sm

X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# %% [markdown]
# ---

# %% [markdown]
# ### <font color='#89cff0'>Model Fitting</font>

# %%
model = sm.OLS(y_train, X_train).fit()

# %%
model.summary(alpha = 0.05)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.481
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                     70.44
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):           3.76e-42
# Time:                        20:40:35   Log-Likelihood:                -1685.0
# No. Observations:                 309   AIC:                             3380.
# Df Residuals:                     304   BIC:                             3399.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        150.7472      3.246     46.439      0.000     144.360     157.135
# ...

# %%
from sklearn.metrics import mean_squared_error

y_pred = model.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print(f'\nRoot Mean Squared Error: {rmse:.4f}')
# Out:
# Root Mean Squared Error: 52.6819

# %% [markdown]
# ---

# %% [markdown]
# ## <font color='#89cff0'>Feature Selection</font>

# %%
remove = ['sex','bp']

new_X_train = X_train.drop(remove, axis =1)
new_X_test = X_test.drop(remove, axis =1)

# %%
model = sm.OLS(y_train, new_X_train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.441
# Method:                 Least Squares   F-statistic:                     122.7
# Date:                Mon, 15 Apr 2024   Prob (F-statistic):           7.56e-40
# Time:                        20:40:35   Log-Likelihood:                -1695.3
# No. Observations:                 309   AIC:                             3397.
# Df Residuals:                     306   BIC:                             3408.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        150.7201      3.346     45.047      0.000     144.136     157.304
# ...

# %%
y_pred = model.predict(new_X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print(f'\nRoot Mean Squared Error: {rmse:.4f}')
# Out:
# Root Mean Squared Error: 52.9224

# %% [markdown]
# ---

# %% [markdown]
# ## <font color='#89cff0'>Residual Analysis Feature Selection</font>

# %%
residuals = y_test - y_pred

plt.figure(figsize=(17, 8))
plt.subplot(1,2,1)
sns.histplot(residuals, bins=50, kde=True, fill=True, alpha=0.7)
plt.title('Distribution of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
sns.kdeplot(residuals, fill=True)
plt.title('Distribution of Residuals')
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## <font color='#89cff0'>Model Validation</font>

# %%
from sklearn.linear_model import LinearRegression

# Reshape 
y_test = np.array(y_test).reshape(-1, 1)
y_pred = np.array(y_pred).reshape(-1, 1)

lm = LinearRegression()
lm.fit(y_test, y_pred)

y_pred_line = lm.predict(y_test)

plt.figure(figsize=(12, 8))
plt.scatter(y_test, y_pred,alpha=0.5, label='Actual vs Predicted')
plt.plot(y_test, y_pred_line, color='red', label='Best Fit')
plt.title('Scatter Plot with Best Fit Line')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <font color='#89cff0'>
#
# 1st model : Root Mean Squared Error: 52.6819
#
#
#
# 2nd model : Root Mean Squared Error: 52.9224
#
#
#
# </font>

# %% [markdown]
# ---
